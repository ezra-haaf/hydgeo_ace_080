# %% [markdown]
# ## Flow to wells: unsteady flow
#
# ### Problem 3

# %% [markdown]
# A confined aquifer with transmissivity $T=600m^2 day^{-1}$ and storativity $S=4\cdot10^{-4}$ is pumped with $Q=1500 m^{3}day^{-1}$.
#
# **What is the drawdown after 1 year at $1 km$ from well**
#
# Use the Theis equation!

# %%
Q=1500/(60*60*24)
r=1000
S=4.0e-4
T=600/(60*60*24)
t=365*24*3600

# %% [markdown]
# Calculate u first. $u=\frac{r^2 S}{4Tt}$

# %% [markdown]
# Go to table:

# %% [markdown]
# ![image.png](attachment:48663f36-82fd-40e7-b9a3-953c1a5d67b4.png)

# %%
W_u=

# %% [markdown]
# Calculate s. $s=\frac{Q*W(u)}{4\pi T}$
